# %%
from numpy import *
from pylab import *
import numpy as np
import numpy.linalg as la
import pyopencl as cl
import pyopencl.array as cl_array
import loopy as lp

# %%
def LU_decomposition(ctx):
  order='C'
  dtype = np.float64
  knl = lp.make_kernel(ctx.devices[0], 
  [
    "{[k,i]: 0<=k<n-1 and k+1<=i<n}",
    "{[j,l]: 0<=k<n-1 and k+1<=j,l<n}",
  ],
  [
  "a[i,k] = a[i,k]/a[k,k] {id=lab1}",
  "a[l,j]= a[l,j] - a[l,k]*a[k,j] {dep=lab1}",
  ],
  [
  lp.GlobalArg("a", dtype, shape = "n, n" , order=order),
  lp.ValueArg("n", np.int32),
  ],
  assumptions="n>=1")
  knl = lp.split_iname(knl, "k", n)
  knl = lp.split_iname(knl, "i", 32)
  knl = lp.split_iname(knl, "j", 32)
  knl = lp.split_iname(knl, "l", 32)

#  print knl
#  print lp.CompiledKernel(ctx, knl).get_highlighted_code()   
  return knl

# %%
def LU_solver(ctx):
  order='C'
  dtype = np.float64
  knl = lp.make_kernel(ctx.devices[0], 
  [
    
    "{[l,k,i,j,m]: 0<=l<r and 0<=k<n-1 and k+1<=i<n and 0<=j<n-1 and 0<=m<n-1-j}",
    
  ],
  [
  "bcopy[i,l] = bcopy[i,l]-bcopy[k,l]*LU[i,k] {id=lab1}",
  "bcopy[n-1-j,l]=bcopy[n-j-1,l]/LU[n-j-1,n-1-j] {id=l2, dep=lab1}",
  "bcopy[m,l]= bcopy[m,l]-bcopy[n-j-1,l]*LU[m,n-1-j] {id=l3, dep =l2}",
  "bcopy[0,l]=bcopy[0,l]/LU[0,0]{id=l4, dep=l2}",
  ],
  [
  lp.GlobalArg("LU", dtype, shape = "n, n" , order=order),
  lp.GlobalArg("bcopy", dtype, shape = "n, r" , order=order),
  lp.ValueArg("n", np.int64),
  lp.ValueArg("r", np.int64),
  ],
  assumptions="n>=1")
#  knl = lp.split_iname(knl, "k", n)
#  knl = lp.split_iname(knl, "i", 32)
#  knl = lp.split_iname(knl, "j", 32)
#  knl = lp.split_iname(knl, "l", 32)

#  print knl
#  print lp.CompiledKernel(ctx, knl).get_highlighted_code()   
  return knl

# %%
def Prav_U(ctx):
  order='C'
  dtype = np.float64
  knl = lp.make_kernel(ctx.devices[0], 
  [
    
    "{[i,j,k,alpha]: 0<=alpha<r and 0<=i,j,k<n}",
    
  ],
  [
    "f[i,alpha]=sum((j,k), a[i,j,k]*v[j,alpha]*w[k,alpha])",
  ],
  [
    lp.GlobalArg("a", dtype, shape=("n, n, n"), order=order),
    lp.GlobalArg("v", dtype, shape=("n, r"), order=order),
    lp.GlobalArg("w", dtype, shape=("n, r"), order=order),
    lp.GlobalArg("f", dtype, shape=("n, r"), order=order),
    lp.ValueArg("n", np.int64),
    lp.ValueArg("r", np.int64),
  ],
  name="pravaya")
  knl = lp.split_iname(knl, "i", 16,outer_tag="g.0", inner_tag="l.0")
  knl = lp.split_iname(knl, "s", 3, outer_tag = "l.1")
  knl = lp.split_iname(knl, "j", 16)
  knl = lp.split_iname(knl, "k", 16) #,16,outer_tag="g.2", inner_tag="l.2")
  
#  knl = lp.split_iname(knl, "k", n)
#  knl = lp.split_iname(knl, "i", 32)
#  knl = lp.split_iname(knl, "j", 32)
#  knl = lp.split_iname(knl, "l", 32)

#  print knl
#  print lp.CompiledKernel(ctx, knl).get_highlighted_code()   
  return knl

# %%
#Опытным путем установлено, что если не смешивать инструкции, то сплиты работают как надо. и вообще все портит только сплит по и 
#и по к кстати тоже
# среднее время работы параллельной версии на процессоре почему-то больше чем непараллельной. a карта вообще отсосала,
# в последних трех строчках в последник трех элементах незадокументированный отсос. неизвестно почему так происходит
# очевидно что оно их просто не заполняет по какой-то неизвестной причине. Внешний цилкл не угадаешь по скольску сплитить потому 
# 127 видимо простое число (так и есть). А еще неожиданно поменялся синтаксиси (ничто не вечно в этом мире) и теперь у меня одна из двух 
# рабочих версий

# %%
n=128
r=3
a=randn(n,n)
a = a.astype(np.float64)
b=randn(n,r)
bcopy=b.copy()

plt = cl.get_platforms()
nvidia_plat = plt[0]
ctx = cl.Context(nvidia_plat.get_devices())



decompose_knl = LU_decomposition(ctx)
queue = cl.CommandQueue(ctx,properties=cl.command_queue_properties.PROFILING_ENABLE)
cknl = lp.CompiledKernel(ctx, decompose_knl)
parameters = {"a": a, "n":n}
evt, (LU) = cknl(queue, **parameters)

LU=LU[0].astype(np.float64)
solve_knl= LU_solver(ctx)
queue = cl.CommandQueue(ctx,properties=cl.command_queue_properties.PROFILING_ENABLE)
cknl = lp.CompiledKernel(ctx, solve_knl)
parameters = {"LU": LU, "bcopy": bcopy, "n":n, "r":r}
evt, (c) = cknl(queue, **parameters)

# %%
f = np.zeros((n, r), dtype = np.float32)
aa = np.random.randn(n, n, n)
v = np.random.randn(n, r)
w = np.random.randn(n,r)

aa = aa.astype(np.float32)
v = v.astype(np.float32)
w = w.astype(np.float32)
parameters = {"a" : aa, "v": v, "w" : w} 


evt, (f) = cknl(queue, **parameters)
# Out:
# array([[[ -3.26050298e-11,   1.12911902e-11,  -3.46132012e-11],
#         [ -2.73416845e-11,   1.04813935e-11,  -3.25250937e-11],
#         [  2.05639950e-11,  -7.65809638e-12,   2.57278643e-11],
#         [ -1.60107483e-11,   8.37230285e-12,  -1.91091587e-11],
#         [ -2.58333632e-12,   5.28632693e-13,  -1.48159263e-12],
#         [  3.09396953e-12,  -4.10615986e-13,   2.22655228e-12],
#         [  5.62327962e-12,  -3.93018951e-12,   6.26565466e-12],
#         [ -1.89563920e-11,   8.72088513e-12,  -2.45155007e-11],
#         [ -1.13171694e-11,   4.87021534e-12,  -1.32960309e-11],
#         [  2.09317008e-11,  -9.14662790e-12,   2.42206255e-11],
#         [  7.99249555e-12,  -3.86890520e-12,   1.07451825e-11],
#         [  3.69251296e-11,  -1.46074264e-11,   4.37427872e-11],
#         [ -1.43836054e-11,   4.38504788e-12,  -1.68909331e-11],
#         [  1.82174276e-11,  -7.29816207e-12,   2.36708431e-11],
#         [  2.46136445e-12,  -1.59017244e-12,   3.18400861e-12],
#         [ -2.43582932e-11,   9.25659549e-12,  -3.19584359e-11],
#         [ -1.49751322e-11,   5.14788212e-12,  -1.65920611e-11],
#         [ -1.03468345e-11,   3.88133969e-12,  -1.24802391e-11],
#         [ -2.22319940e-11,   7.58304530e-12,  -2.60680366e-11],
#         [  8.36475333e-12,  -2.39475106e-12,   1.01896269e-11],
#         [ -1.71427317e-11,   7.00883795e-12,  -1.99231742e-11],
#         [ -4.46291892e-11,   1.71782588e-11,  -5.29016830e-11],
#         [  8.47677484e-12,  -2.95108382e-12,   1.14654952e-11],
#         [  3.42170736e-13,  -5.57554003e-13,   1.51550994e-12],
#         [  4.84945417e-12,  -1.51673119e-12,   5.98920913e-12],
#         [  2.18669527e-11,  -9.31255073e-12,   2.71977996e-11],
#         [  3.43201023e-11,  -1.26003652e-11,   4.13749035e-11],
#         [ -1.87205806e-11,   7.99582622e-12,  -2.26032526e-11],
#         [ -1.89642746e-12,   2.14545048e-12,  -1.45505830e-12],
#         [ -1.16255894e-11,   3.95702915e-12,  -1.34798839e-11],
#         [  3.59605679e-11,  -1.41522349e-11,   4.47002435e-11],
#         [  4.72795136e-11,  -1.88316029e-11,   5.52748958e-11],
#         [ -3.02602388e-11,   1.21178623e-11,  -3.49951179e-11],
#         [ -1.63480340e-12,   4.51083615e-13,  -1.50279789e-12],
#         [ -9.12492304e-12,   4.35934622e-12,  -1.16400223e-11],
#         [  1.54014579e-11,  -5.08304510e-12,   1.97855066e-11],
#         [ -2.12754259e-11,   9.24704757e-12,  -2.35802489e-11],
#         [ -1.03010933e-11,   3.78730380e-12,  -1.39070977e-11],
#         [  1.54765090e-11,  -8.21470669e-12,   1.95967687e-11],
#         [  2.00022221e-11,  -8.01131383e-12,   2.25401919e-11],
#         [ -8.19150303e-13,  -1.61635982e-12,  -5.97077943e-13],
#         [ -2.04938289e-11,   8.52917736e-12,  -2.45767851e-11],
#         [  1.88071780e-11,  -6.35203001e-12,   2.47126763e-11],
#         [  1.71453962e-11,  -5.52269341e-12,   2.12931894e-11],
#         [  1.03250741e-13,   1.16795462e-12,  -1.82420745e-12],
#         [  4.10227408e-12,  -8.97726338e-13,   5.42188516e-12],
#         [  5.04885023e-12,  -8.52207194e-13,   5.36259925e-12],
#         [ -4.91997554e-11,   1.79518622e-11,  -5.67066394e-11],
#         [ -1.24842359e-11,   4.22328839e-12,  -1.48761004e-11],
#         [  7.12185866e-12,  -3.24390514e-12,   7.06801284e-12],
#         [  2.74891221e-12,  -6.08846307e-13,   4.49196236e-12],
#         [ -1.85496063e-11,   6.81810164e-12,  -2.17763585e-11],
#         [  8.03490607e-12,  -2.84439139e-12,   1.02304831e-11],
#         [  1.16211485e-11,  -4.44905224e-12,   1.25628397e-11],
#         [ -1.49436019e-11,   6.08968431e-12,  -1.83937310e-11],
#         [ -1.21493926e-11,   4.79530304e-12,  -1.50435220e-11],
#         [  2.44151366e-11,  -9.46975831e-12,   2.77751155e-11],
#         [  4.07123224e-11,  -1.54716240e-11,   4.95710140e-11],
#         [  2.06936690e-11,  -7.63311636e-12,   2.69659850e-11],
#         [  3.95938837e-12,  -1.50879309e-12,   4.15534274e-12],
#         [  6.49746923e-12,  -2.51365595e-12,   7.29749594e-12],
#         [  1.38333789e-13,   3.64153152e-14,   3.35181882e-12],
#         [  1.44497747e-11,  -5.43920464e-12,   1.70876646e-11],
#         [ -4.66249261e-12,   1.90786276e-12,  -5.86219961e-12],
#         [  6.60649313e-12,  -2.94075875e-12,   7.72337749e-12],
#         [ -2.69393396e-11,   1.00244257e-11,  -3.22257776e-11],
#         [ -1.43800527e-11,   5.36570788e-12,  -1.73905335e-11],
#         [ -1.39488421e-11,   4.95203878e-12,  -1.86015647e-11],
#         [ -4.13624690e-11,   1.54742885e-11,  -5.09103870e-11],
#         [  4.53468374e-11,  -1.74877890e-11,   5.45057333e-11],
#         [ -1.15973897e-11,   4.64783767e-12,  -1.37005962e-11],
#         [ -1.09023901e-12,   3.47017554e-13,  -8.87609430e-13],
#         [  3.57998076e-11,  -1.37365674e-11,   4.29913882e-11],
#         [  1.70916614e-11,  -6.68648470e-12,   2.02620143e-11],
#         [  1.00626174e-11,  -3.86846111e-12,   1.20761179e-11],
#         [ -2.54374299e-11,   9.64828217e-12,  -3.05346859e-11],
#         [  1.73647763e-11,  -6.30473451e-12,   2.12345697e-11],
#         [ -1.04356523e-11,   3.83670873e-12,  -1.27398092e-11],
#         [  1.26283428e-11,  -4.87543339e-12,   1.49644741e-11],
#         [ -9.15734155e-12,   3.85014243e-12,  -1.07363007e-11],
#         [ -9.16688947e-12,   3.25983684e-12,  -1.11586296e-11],
#         [  1.20206067e-11,  -4.47131221e-12,   1.47641899e-11],
#         [  3.55093732e-11,  -1.35500500e-11,   4.27036184e-11],
#         [ -1.64455116e-11,   6.03073147e-12,  -2.02433625e-11],
#         [ -3.67261777e-11,   1.41462397e-11,  -4.34372538e-11],
#         [ -1.93791649e-11,   7.49578177e-12,  -2.33635333e-11],
#         [  3.68005626e-12,  -1.37101441e-12,   4.31843450e-12],
#         [ -2.09565698e-12,   4.31654712e-13,  -2.30993003e-12],
#         [ -5.54116752e-11,   2.07585060e-11,  -6.64517330e-11],
#         [ -3.56781271e-11,   1.35536027e-11,  -4.30162572e-11],
#         [ -3.08499892e-11,   1.16302523e-11,  -3.68176600e-11],
#         [  2.84909873e-11,  -1.10311760e-11,   3.37960770e-11],
#         [  1.90691907e-11,  -7.44448947e-12,   2.27702301e-11],
#         [ -2.55342414e-11,   9.73798819e-12,  -3.05346859e-11],
#         [  2.08313367e-11,  -8.12233614e-12,   2.44231302e-11],
#         [ -2.14330775e-11,   8.56970050e-12,  -2.54214427e-11],
#         [ -1.28044242e-11,   4.98495689e-12,  -1.51878510e-11],
#         [ -1.90132354e-11,   7.42628181e-12,  -2.28128627e-11],
#         [  9.68558567e-12,  -3.71902509e-12,   1.14677157e-11],
#         [  1.22937216e-11,  -4.59410288e-12,   1.47490908e-11],
#         [ -2.31761277e-11,   8.84226026e-12,  -2.85673707e-11],
#         [  3.56878971e-11,  -1.40052414e-11,   4.27622382e-11],
#         [  3.66562336e-12,  -1.29307676e-12,   4.24948965e-12],
#         [ -1.85433890e-11,   6.87361279e-12,  -2.20001795e-11],
#         [  1.86028970e-12,  -9.23816579e-13,   2.13978835e-12],
#         [  5.34594591e-12,  -2.32081021e-12,   6.74704737e-12],
#         [ -5.38769029e-12,   1.79550819e-12,  -6.49724718e-12],
#         [ -2.19166907e-11,   7.84305954e-12,  -2.69482214e-11],
#         [ -1.85149673e-11,   7.66997577e-12,  -2.22337704e-11],
#         [  1.96314076e-11,  -7.22222282e-12,   2.33884023e-11],
#         [  8.98170427e-12,  -3.63287178e-12,   1.10884635e-11],
#         [  5.64542857e-12,  -2.35916842e-12,   6.74793554e-12],
#         [  7.88391574e-12,  -2.89768209e-12,   9.78594983e-12],
#         [ -3.46567219e-12,   1.20577159e-12,  -4.18509671e-12],
#         [ -4.97801800e-12,   2.04641859e-12,  -6.11044548e-12],
#         [  9.31665856e-12,  -3.81750187e-12,   1.11626264e-11],
#         [  2.94431146e-11,  -1.07855946e-11,   3.57003316e-11],
#         [  3.57012198e-11,  -1.36046729e-11,   4.27249347e-11],
#         [ -2.25712782e-11,   8.49631476e-12,  -2.70965472e-11],
#         [  1.73687731e-11,  -6.60449473e-12,   2.03606021e-11],
#         [  2.52029508e-11,  -9.76596581e-12,   3.03694847e-11],
#         [ -1.77831083e-11,   6.40332232e-12,  -2.16777707e-11],
#         [  2.34932074e-11,  -8.34887715e-12,   2.84909873e-11],
#         [  2.80797607e-11,  -1.04103393e-11,   3.34372530e-11],
#         [ -1.18234311e-11,   4.45510295e-12,  -1.41127110e-11],
#         [  5.99209571e-12,  -2.04769535e-12,   7.24531546e-12],
#         [ -1.13269394e-11,   4.06030765e-12,  -1.41548995e-11],
#         [ -2.17355023e-11,   8.23097146e-12,  -2.59596789e-11]]])

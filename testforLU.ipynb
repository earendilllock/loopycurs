# %%
from numpy import *
from pylab import *
import numpy as np
import numpy.linalg as la
import pyopencl as cl
import pyopencl.array as cl_array
import loopy as lp

# %%
def LU_decomposition(ctx):
  order='C'
  dtype = np.float64
  knl = lp.make_kernel(ctx.devices[0], 
  [
    "{[k,i]: 0<=k<n-1 and k+1<=i<n}",
    "{[j,l]: 0<=k<n-1 and k+1<=j,l<n}",
  ],
  [
  "a[i,k] = a[i,k]/a[k,k] {id=lab1}",
  "a[l,j]= a[l,j] - a[l,k]*a[k,j] {dep=lab1}",
  ],
  [
  lp.GlobalArg("a", dtype, shape = "n, n" , order=order),
  lp.ValueArg("n", np.int32),
  ],
  assumptions="n>=1")
  knl = lp.split_iname(knl, "k", n)
  knl = lp.split_iname(knl, "i", 32)
  knl = lp.split_iname(knl, "j", 32)
  knl = lp.split_iname(knl, "l", 32)

#  print knl
#  print lp.CompiledKernel(ctx, knl).get_highlighted_code()   
  return knl

# %%
def LU_solver(ctx):
  order='C'
  dtype = np.float64
  knl = lp.make_kernel(ctx.devices[0], 
  [
    
    "{[l,k,i,j,m]: 0<=l<r and 0<=k<n-1 and k+1<=i<n and 0<=j<n-1 and 0<=m<n-1-j}",
    
  ],
  [
  "bcopy[i,l] = bcopy[i,l]-bcopy[k,l]*LU[i,k] {id=lab1}",
  "bcopy[n-1-j,l]=bcopy[n-j-1,l]/LU[n-j-1,n-1-j] {id=l2, dep=lab1}",
  "bcopy[m,l]= bcopy[m,l]-bcopy[n-j-1,l]*LU[m,n-1-j] {id=l3, dep =l2}",
  "bcopy[0,l]=bcopy[0,l]/LU[0,0]{id=l4, dep=l2}",
  ],
  [
  lp.GlobalArg("LU", dtype, shape = "n, n" , order=order),
  lp.GlobalArg("bcopy", dtype, shape = "n, r" , order=order),
  lp.ValueArg("n", np.int64),
  lp.ValueArg("r", np.int64),
  ],
  assumptions="n>=1")
#  knl = lp.split_iname(knl, "k", n)
#  knl = lp.split_iname(knl, "i", 32)
#  knl = lp.split_iname(knl, "j", 32)
#  knl = lp.split_iname(knl, "l", 32)

#  print knl
#  print lp.CompiledKernel(ctx, knl).get_highlighted_code()   
  return knl

# %%
def Prav_U(ctx):
  order='C'
  dtype = np.float64
  knl = lp.make_kernel(ctx.devices[0], 
  [
    
    "{[i,j,k,alpha]: 0<=alpha<r and 0<=i,j,k<n}",
    
  ],
  [
    "f[i,alpha]=sum((j,k), a[i,j,k]*v[j,alpha]*w[k,alpha])",
  ],
  [
    lp.GlobalArg("a", dtype, shape="n, n, n", order=order),
    lp.GlobalArg("v", dtype, shape="n, r", order=order),
    lp.GlobalArg("w", dtype, shape="n, r", order=order),
    lp.GlobalArg("f", dtype, shape="n, r", order=order),
    lp.ValueArg("n", np.int64),
    lp.ValueArg("r", np.int64),
  ],
  assumptions="n>=1")
  knl = lp.split_iname(knl, "i", 16,outer_tag="g.0", inner_tag="l.0")
  knl = lp.split_iname(knl, "alpha", 3, outer_tag="g.1", inner_tag="l.1")
  knl = lp.split_iname(knl, "j", 16)
  knl = lp.split_iname(knl, "k", 16) #,16,outer_tag="g.2", inner_tag="l.2")
  
#  knl = lp.split_iname(knl, "k", n)
#  knl = lp.split_iname(knl, "i", 32)
#  knl = lp.split_iname(knl, "j", 32)
#  knl = lp.split_iname(knl, "l", 32)

#  print knl
#  print lp.CompiledKernel(ctx, knl).get_highlighted_code()   
  return knl

# %%
def Prav_V(ctx):
  order='C'
  dtype = np.float64
  knl = lp.make_kernel(ctx.devices[0], 
  [
    
    "{[i,j,k,alpha]: 0<=alpha<r and 0<=i,j,k<n}",
    
  ],
  [
    "f[j,alpha]=sum((k,i), a[i,j,k]*w[k,alpha]*u[i,alpha])",
  ],
  [
    lp.GlobalArg("a", dtype, shape="n, n, n", order=order),
    lp.GlobalArg("u", dtype, shape="n, r", order=order),
    lp.GlobalArg("w", dtype, shape="n, r", order=order),
    lp.GlobalArg("f", dtype, shape="n, r", order=order),
    lp.ValueArg("n", np.int64),
    lp.ValueArg("r", np.int64),
  ],
  assumptions="n>=1")
  knl = lp.split_iname(knl, "j", 16,outer_tag="g.0", inner_tag="l.0")
  knl = lp.split_iname(knl, "alpha", 3, outer_tag="g.1", inner_tag="l.1")
  knl = lp.split_iname(knl, "i", 16)
  knl = lp.split_iname(knl, "k", 16) #,16,outer_tag="g.2", inner_tag="l.2")
   
  return knl

# %%
def Prav_W(ctx):
  order='C'
  dtype = np.float64
  knl = lp.make_kernel(ctx.devices[0], 
  [
    
    "{[i,j,k,alpha]: 0<=alpha<r and 0<=i,j,k<n}",
    
  ],
  [
    "f[k,alpha]=sum((i,j), a[i,j,k]*u[i,alpha]*v[j,alpha])",
  ],
  [
    lp.GlobalArg("a", dtype, shape="n, n, n", order=order),
    lp.GlobalArg("v", dtype, shape="n, r", order=order),
    lp.GlobalArg("u", dtype, shape="n, r", order=order),
    lp.GlobalArg("f", dtype, shape="n, r", order=order),
    lp.ValueArg("n", np.int64),
    lp.ValueArg("r", np.int64),
  ],
  assumptions="n>=1")
  knl = lp.split_iname(knl, "k", 16,outer_tag="g.0", inner_tag="l.0")
  knl = lp.split_iname(knl, "alpha", 3, outer_tag="g.1", inner_tag="l.1")
  knl = lp.split_iname(knl, "j", 16)
  knl = lp.split_iname(knl, "i", 16) 
  

  return knl

# %%
def Prav_U(ctx):
  order='C'
  dtype = np.float64
  knl = lp.make_kernel(ctx.devices[0], 
  [
    
    "{[i,j,k,alpha]: 0<=alpha<r and 0<=i,j,k<n}",
    
  ],
  [
    "f[i,alpha]=sum((j,k), a[i,j,k]*v[j,alpha]*w[k,alpha])",
  ],
  [
    lp.GlobalArg("a", dtype, shape="n, n, n", order=order),
    lp.GlobalArg("v", dtype, shape="n, r", order=order),
    lp.GlobalArg("w", dtype, shape="n, r", order=order),
    lp.GlobalArg("f", dtype, shape="n, r", order=order),
    lp.ValueArg("n", np.int64),
    lp.ValueArg("r", np.int64),
  ],
  assumptions="n>=1")
  knl = lp.split_iname(knl, "i", 16,outer_tag="g.0", inner_tag="l.0")
  knl = lp.split_iname(knl, "alpha", 3, outer_tag="g.1", inner_tag="l.1")
  knl = lp.split_iname(knl, "j", 16)
  knl = lp.split_iname(knl, "k", 16) #,16,outer_tag="g.2", inner_tag="l.2")
  
#  knl = lp.split_iname(knl, "k", n)
#  knl = lp.split_iname(knl, "i", 32)
#  knl = lp.split_iname(knl, "j", 32)
#  knl = lp.split_iname(knl, "l", 32)

#  print knl
#  print lp.CompiledKernel(ctx, knl).get_highlighted_code()   
  return knl

# %%
#Опытным путем установлено, что если не смешивать инструкции, то сплиты работают как надо. и вообще все портит только сплит по и 
#и по к кстати тоже
# среднее время работы параллельной версии на процессоре почему-то больше чем непараллельной. a карта вообще отсосала,
# в последних трех строчках в последник трех элементах незадокументированный отсос. неизвестно почему так происходит
# очевидно что оно их просто не заполняет по какой-то неизвестной причине. Внешний цилкл не угадаешь по скольску сплитить потому 
# 127 видимо простое число (так и есть). А еще неожиданно поменялся синтаксиси (ничто не вечно в этом мире) и теперь у меня одна из двух 
# рабочих версий

# %%
n=128
r=3
a=randn(n,n)
a = a.astype(np.float64)
b=randn(n,r)
bcopy=b.copy()

plt = cl.get_platforms()
nvidia_plat = plt[0]
ctx = cl.Context(nvidia_plat.get_devices())



decompose_knl = LU_decomposition(ctx)
queue = cl.CommandQueue(ctx,properties=cl.command_queue_properties.PROFILING_ENABLE)
cknl = lp.CompiledKernel(ctx, decompose_knl)
parameters = {"a": a, "n":n}
evt, (LU) = cknl(queue, **parameters)

LU=LU[0].astype(np.float64)
solve_knl= LU_solver(ctx)
queue = cl.CommandQueue(ctx,properties=cl.command_queue_properties.PROFILING_ENABLE)
cknl = lp.CompiledKernel(ctx, solve_knl)
parameters = {"LU": LU, "bcopy": bcopy, "n":n, "r":r}
evt, (c) = cknl(queue, **parameters)

# %%
knl = Prav_V(ctx)
f = np.zeros((n, r), dtype = np.float32)
aa = np.random.randn(n, n, n)
v = np.random.randn(n, r)
w = np.random.randn(n,r)

queue = cl.CommandQueue(ctx,properties=cl.command_queue_properties.PROFILING_ENABLE)
cknl = lp.CompiledKernel(ctx, knl)


parameters = {"a" : aa, "u": v, "w" : w, "n":n,"r":r} 


evt, (f) = cknl(queue, **parameters)

# %%
fuu=zeros((n,r))
for j in xrange (0,n):
    for s in xrange(0,r):
       l=0
       for i in xrange(0,n):
            h=0
            for k in xrange(0,n):
                h=h+aa[i,j,k]*w[k,s]
            l=l+h*v[i,s]
       fuu[j,s]=l

# %%
fuu-f[0]
# Out:
# array([[ -1.33582034e-12,  -3.83693077e-13,   1.56319402e-13],
#        [  3.46744855e-12,  -7.46069873e-14,   5.40012479e-13],
#        [ -2.91322522e-13,  -1.35003120e-13,  -2.84217094e-14],
#        [ -3.83693077e-13,   1.63424829e-13,   1.70530257e-13],
#        [ -1.42108547e-14,   4.05009359e-13,   4.26325641e-14],
#        [  4.26325641e-14,   7.46069873e-14,   1.36335387e-13],
#        [ -1.36424205e-12,  -1.20792265e-13,   2.27373675e-13],
#        [  1.13686838e-13,  -3.55271368e-13,  -3.55271368e-13],
#        [  1.70530257e-13,   1.81188398e-13,  -9.94759830e-14],
#        [ -1.08002496e-12,   3.26849658e-13,  -3.12638804e-13],
#        [  2.34479103e-13,  -1.42108547e-14,   5.82645043e-13],
#        [ -2.84217094e-14,   4.08562073e-13,   6.67910172e-13],
#        [ -2.84217094e-13,   1.33226763e-13,  -7.10542736e-14],
#        [ -7.67386155e-13,  -2.13162821e-13,  -1.27897692e-13],
#        [ -1.70530257e-13,  -4.90274488e-13,  -3.41060513e-13],
#        [ -1.70530257e-13,   2.55795385e-13,  -5.68434189e-14],
#        [  5.32907052e-15,  -2.84217094e-14,   1.42108547e-13],
#        [ -4.26325641e-13,   3.55271368e-14,  -6.25277607e-13],
#        [ -2.13162821e-13,   5.54223334e-13,   2.91322522e-13],
#        [ -3.97903932e-13,  -2.27373675e-13,  -4.97379915e-14],
#        [  3.41060513e-13,  -1.27897692e-13,  -9.09494702e-13],
#        [ -4.26325641e-13,   3.12638804e-13,   7.10542736e-13],
#        [ -2.84217094e-14,   1.42108547e-13,   9.37916411e-13],
#        [ -4.68958206e-13,   5.11590770e-13,   4.26325641e-14],
#        [ -1.70530257e-13,  -1.42108547e-13,   7.38964445e-13],
#        [  1.70530257e-13,  -3.90798505e-13,  -5.68434189e-14],
#        [ -7.38964445e-13,   8.24229573e-13,  -5.68434189e-14],
#        [  2.34479103e-13,   8.52651283e-13,  -3.33955086e-13],
#        [ -1.20792265e-13,  -4.05009359e-13,  -8.52651283e-14],
#        [  5.54223334e-13,  -1.06581410e-13,   4.26325641e-14],
#        [  7.10542736e-14,  -4.83169060e-13,   3.41060513e-13],
#        [ -1.84741111e-13,  -3.48165941e-13,  -9.94759830e-14],
#        [ -2.84217094e-14,  -2.55795385e-13,   1.06581410e-13],
#        [ -3.69482223e-13,   5.96855898e-13,  -3.30402372e-13],
#        [  1.56319402e-13,   6.75015599e-14,   2.22044605e-13],
#        [  3.97903932e-13,   4.33431069e-13,   9.94759830e-14],
#        [ -1.05160325e-12,  -2.02504680e-13,  -3.41060513e-13],
#        [ -4.12114787e-13,  -5.82645043e-13,  -8.52651283e-14],
#        [  6.53699317e-13,   1.56319402e-13,   2.41584530e-13],
#        [  5.68434189e-14,  -8.02913291e-13,   1.47792889e-12],
#        [ -6.46593890e-13,   9.94759830e-13,  -9.09494702e-13],
#        [  8.52651283e-14,   1.44950718e-12,  -1.22213351e-12],
#        [ -5.68434189e-14,  -6.39488462e-14,   1.22213351e-12],
#        [ -9.09494702e-13,   2.84217094e-13,   7.38964445e-13],
#        [ -1.30739863e-12,   1.98951966e-13,  -2.70006240e-13],
#        [  2.70006240e-13,   5.11590770e-13,  -1.56319402e-13],
#        [  2.33058017e-12,  -1.42108547e-14,  -1.20792265e-13],
#        [ -1.30739863e-12,  -3.83693077e-13,   4.26325641e-13],
#        [ -1.84741111e-13,   1.56319402e-13,  -3.83693077e-13],
#        [  2.55795385e-13,  -5.93303184e-13,   5.68434189e-14],
#        [ -2.27373675e-13,   4.26325641e-14,   8.43769499e-14],
#        [  5.11590770e-13,  -2.41584530e-13,  -2.84217094e-13],
#        [  6.60804744e-13,  -1.27897692e-13,   5.96855898e-13],
#        [ -9.94759830e-14,  -1.49213975e-13,  -5.68434189e-14],
#        [  7.38964445e-13,   4.40536496e-13,   2.70006240e-13],
#        [  2.41584530e-13,   4.83169060e-13,   7.10542736e-13],
#        [  9.94759830e-13,  -2.70006240e-13,   8.88178420e-14],
#        [ -5.68434189e-14,  -3.55271368e-13,   4.44089210e-14],
#        [  5.18696197e-13,   1.56319402e-13,  -1.00897068e-12],
#        [  2.84217094e-14,   1.91846539e-13,   5.68434189e-14],
#        [  1.70530257e-13,  -2.34479103e-13,  -1.98951966e-13],
#        [ -5.11590770e-13,   4.76063633e-13,  -5.68434189e-13],
#        [  1.42108547e-13,   7.81597009e-14,   8.52651283e-14],
#        [  8.88178420e-14,   7.63833441e-14,  -2.34479103e-13],
#        [  7.10542736e-14,   2.98427949e-13,  -1.84741111e-13],
#        [  2.84217094e-14,  -9.94759830e-14,  -3.19744231e-13],
#        [  5.29354338e-13,  -2.55795385e-13,   2.02504680e-13],
#        [ -4.61852778e-14,   1.42108547e-13,  -1.93267624e-12],
#        [  3.97903932e-13,  -4.12114787e-13,   5.68434189e-14],
#        [  3.26849658e-13,  -1.70530257e-13,  -4.26325641e-13],
#        [  9.09494702e-13,   1.27897692e-13,   1.56319402e-13],
#        [  3.19744231e-14,   8.52651283e-13,  -1.42108547e-14],
#        [  1.98951966e-13,   2.27373675e-13,  -8.52651283e-14],
#        [ -5.40012479e-13,  -1.84741111e-13,   1.95399252e-14],
#        [ -1.13686838e-13,   3.41060513e-13,   4.97379915e-13],
#        [ -7.10542736e-14,   1.84741111e-13,  -4.83169060e-13],
#        [  6.39488462e-13,   2.84217094e-13,  -1.74082970e-13],
#        [  5.68434189e-14,  -4.54747351e-13,   3.24185123e-14],
#        [  8.52651283e-14,   3.55271368e-14,   1.98951966e-13],
#        [  1.70530257e-13,   4.12114787e-13,   2.27373675e-13],
#        [  4.26325641e-13,  -5.68434189e-14,  -2.55795385e-13],
#        [  1.05160325e-12,   0.00000000e+00,   1.35447209e-13],
#        [  5.40012479e-13,  -1.84741111e-13,   1.86517468e-13],
#        [  1.49213975e-13,  -1.08002496e-12,  -1.56319402e-13],
#        [  1.42108547e-13,  -3.41060513e-13,   7.10542736e-13],
#        [  5.11590770e-13,   1.17239551e-13,   3.19744231e-13],
#        [ -4.54747351e-13,  -2.94875235e-13,   1.56319402e-13],
#        [  4.08562073e-14,   4.54747351e-13,   2.13162821e-13],
#        [ -5.11590770e-13,   5.64881475e-13,  -3.26849658e-13],
#        [ -2.55795385e-13,  -1.42108547e-13,   2.13162821e-13],
#        [ -6.53699317e-13,   1.77635684e-14,   2.84217094e-13],
#        [  2.55795385e-13,   8.24229573e-13,   1.63424829e-13],
#        [  3.41060513e-13,  -1.03028697e-13,   3.30402372e-13],
#        [ -2.48689958e-13,  -2.77111667e-13,  -7.24753590e-13],
#        [  4.01456646e-13,   4.61852778e-14,   4.90274488e-13],
#        [ -8.34887715e-14,  -1.98951966e-13,  -1.05693232e-13],
#        [ -4.14446255e-13,  -1.44950718e-12,   8.08242362e-14],
#        [ -1.42108547e-13,  -7.10542736e-14,   1.49213975e-13],
#        [ -2.84217094e-14,  -9.94759830e-14,  -2.59348099e-13],
#        [  2.98427949e-13,   4.97379915e-14,  -8.38440428e-13],
#        [ -5.68434189e-14,   1.59161573e-12,   1.20792265e-13],
#        [ -7.38964445e-13,  -1.24344979e-13,   9.94759830e-14],
#        [ -3.62376795e-13,  -3.62376795e-13,  -5.11590770e-13],
#        [ -3.41060513e-13,  -6.82121026e-13,   4.97379915e-13],
#        [  2.62900812e-13,   2.27373675e-13,   6.39488462e-14],
#        [ -8.52651283e-13,   7.67386155e-13,  -1.13686838e-13],
#        [  1.56319402e-13,   5.68434189e-14,   6.75015599e-13],
#        [  5.96855898e-13,   5.40012479e-13,  -3.05533376e-13],
#        [  2.98427949e-13,  -3.55271368e-13,   8.38440428e-13],
#        [ -1.02318154e-12,   0.00000000e+00,   5.96855898e-13],
#        [ -1.13686838e-13,   2.25597319e-13,  -1.13686838e-13],
#        [  1.16529009e-12,  -2.13162821e-14,  -1.13686838e-13],
#        [  3.94351218e-13,   7.17648163e-13,  -3.41060513e-13],
#        [  1.17239551e-13,  -2.55795385e-13,   2.48689958e-13],
#        [  5.96855898e-13,   6.96331881e-13,   9.23705556e-14],
#        [ -3.69482223e-13,  -4.19220214e-13,  -2.91322522e-13],
#        [  4.97379915e-14,   1.90425453e-12,   3.55271368e-13],
#        [  1.56319402e-13,  -7.38964445e-13,  -3.97903932e-13],
#        [  6.39488462e-13,  -1.42108547e-13,   2.13162821e-14],
#        [ -1.35003120e-13,  -2.73558953e-13,  -2.84217094e-14],
#        [  1.08002496e-12,   1.27897692e-13,   4.15667500e-13],
#        [ -2.27373675e-12,   7.24753590e-13,  -3.97903932e-13],
#        [ -2.09610107e-13,   2.62900812e-13,  -1.70530257e-13],
#        [  1.77635684e-13,  -2.55795385e-13,  -8.52651283e-13],
#        [ -9.23705556e-14,  -4.05897538e-13,  -2.69118061e-13],
#        [ -2.30926389e-14,   0.00000000e+00,  -3.76587650e-13],
#        [ -9.09494702e-13,  -1.45661261e-13,  -3.55271368e-15],
#        [ -3.12638804e-13,   7.10542736e-14,  -1.56319402e-13]])
